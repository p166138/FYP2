# %%
import random
import cv2
import numpy as np
import pandas as pd
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, precision_score, recall_score
from tensorflow.keras import layers
from tensorflow.keras.callbacks import Callback, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten, Input
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD, Adam, RMSprop
from tensorflow.keras.optimizers import schedules
from tensorflow.keras.applications.resnet50 import ResNet50
import matplotlib.pyplot as plt
from tensorflow.keras.utils import to_categorical
import os
os.environ['TF_FORCE_GPU_ALLOW_GROWTH'] = 'true'

# %%
# Initialize
epochs = 50
learning_rate = 2e-5
batch_size = 8
img_dims =  (228,400,3)

# %%
X_train = np.load("malignant_resized(228x400)/X_train-228x400.npy")
y_train = np.load("malignant_resized(228x400)/y_train-228x400.npy")
X_test = np.load("malignant_resized(228x400)/X_test-228x400.npy")
y_test = np.load("malignant_resized(228x400)/y_test-228x400.npy")

# %%
y_train = to_categorical(y_train) 
y_test = to_categorical(y_test)

# %%
restnet = ResNet50(include_top=False, weights='imagenet', input_shape=img_dims)
output = restnet.layers[-1].output
output = Flatten()(output)
restnet = Model(restnet.input, output)
for layer in restnet.layers:
    layer.trainable = False
restnet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 228, 400, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 234, 406, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 114, 200, 64) 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, 114, 200, 64) 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, 114, 200, 64) 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 116, 202, 64) 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 57, 100, 64)  0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 57, 100, 64)  4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 57, 100, 64)  256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 57, 100, 64)  0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 57, 100, 64)  36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 57, 100, 64)  256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 57, 100, 64)  0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 57, 100, 256) 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 57, 100, 256) 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, 57, 100, 256) 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, 57, 100, 256) 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, 57, 100, 256) 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, 57, 100, 256) 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 57, 100, 64)  16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 57, 100, 64)  256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 57, 100, 64)  0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 57, 100, 64)  36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 57, 100, 64)  256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 57, 100, 64)  0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 57, 100, 256) 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, 57, 100, 256) 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, 57, 100, 256) 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, 57, 100, 256) 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 57, 100, 64)  16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 57, 100, 64)  256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 57, 100, 64)  0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 57, 100, 64)  36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 57, 100, 64)  256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 57, 100, 64)  0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 57, 100, 256) 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, 57, 100, 256) 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, 57, 100, 256) 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, 57, 100, 256) 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 29, 50, 128)  32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 29, 50, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 29, 50, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 29, 50, 128)  147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 29, 50, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 29, 50, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 29, 50, 512)  131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 29, 50, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, 29, 50, 512)  2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, 29, 50, 512)  2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, 29, 50, 512)  0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, 29, 50, 512)  0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 29, 50, 128)  65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 29, 50, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 29, 50, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 29, 50, 128)  147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 29, 50, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 29, 50, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 29, 50, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, 29, 50, 512)  2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, 29, 50, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, 29, 50, 512)  0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 29, 50, 128)  65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 29, 50, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 29, 50, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 29, 50, 128)  147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 29, 50, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 29, 50, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 29, 50, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, 29, 50, 512)  2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, 29, 50, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, 29, 50, 512)  0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 29, 50, 128)  65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 29, 50, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 29, 50, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 29, 50, 128)  147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 29, 50, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 29, 50, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 29, 50, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, 29, 50, 512)  2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, 29, 50, 512)  0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, 29, 50, 512)  0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 15, 25, 256)  131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 15, 25, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 15, 25, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 15, 25, 256)  590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 15, 25, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 15, 25, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 15, 25, 1024) 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 15, 25, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, 15, 25, 1024) 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, 15, 25, 1024) 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, 15, 25, 1024) 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, 15, 25, 1024) 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 15, 25, 256)  262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 15, 25, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 15, 25, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 15, 25, 256)  590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 15, 25, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 15, 25, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 15, 25, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, 15, 25, 1024) 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, 15, 25, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, 15, 25, 1024) 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 15, 25, 256)  262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 15, 25, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 15, 25, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 15, 25, 256)  590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 15, 25, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 15, 25, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 15, 25, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, 15, 25, 1024) 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, 15, 25, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, 15, 25, 1024) 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 15, 25, 256)  262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 15, 25, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 15, 25, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 15, 25, 256)  590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 15, 25, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 15, 25, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 15, 25, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, 15, 25, 1024) 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, 15, 25, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, 15, 25, 1024) 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 15, 25, 256)  262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 15, 25, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 15, 25, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 15, 25, 256)  590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 15, 25, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 15, 25, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 15, 25, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, 15, 25, 1024) 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, 15, 25, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, 15, 25, 1024) 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 15, 25, 256)  262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 15, 25, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 15, 25, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 15, 25, 256)  590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 15, 25, 256)  1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 15, 25, 256)  0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 15, 25, 1024) 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, 15, 25, 1024) 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, 15, 25, 1024) 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, 15, 25, 1024) 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 8, 13, 512)   524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 8, 13, 512)   2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 8, 13, 512)   0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 8, 13, 512)   2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 8, 13, 512)   2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 8, 13, 512)   0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 8, 13, 2048)  2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 8, 13, 2048)  1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, 8, 13, 2048)  8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, 8, 13, 2048)  8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, 8, 13, 2048)  0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, 8, 13, 2048)  0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 8, 13, 512)   1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 8, 13, 512)   2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 8, 13, 512)   0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 8, 13, 512)   2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 8, 13, 512)   2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 8, 13, 512)   0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 8, 13, 2048)  1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, 8, 13, 2048)  8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, 8, 13, 2048)  0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, 8, 13, 2048)  0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 8, 13, 512)   1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 8, 13, 512)   2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 8, 13, 512)   0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 8, 13, 512)   2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 8, 13, 512)   2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 8, 13, 512)   0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 8, 13, 2048)  1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, 8, 13, 2048)  8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, 8, 13, 2048)  0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, 8, 13, 2048)  0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 212992)       0           conv5_block3_out[0][0]
# ==================================================================================================
# Total params: 23,587,712
# Trainable params: 0
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
restnet.trainable = True
set_trainable = False
for layer in restnet.layers:
    if layer.name in ['conv5_block3_2_conv', 'conv5_block3_3_conv', 'conv5_block3_2_relu']:
        set_trainable = True
    if set_trainable:
        layer.trainable = True
    else:
        layer.trainable = False
layers = [(layer, layer.name, layer.trainable) for layer in restnet.layers]
pd.DataFrame(layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                             Layer Type           Layer Name  \
# 0    <tensorflow.python.keras.engine.input_layer.In...              input_1
# 1    <tensorflow.python.keras.layers.convolutional....            conv1_pad
# 2    <tensorflow.python.keras.layers.convolutional....           conv1_conv
# 3    <tensorflow.python.keras.layers.normalization_...             conv1_bn
# 4    <tensorflow.python.keras.layers.core.Activatio...           conv1_relu
# ..                                                 ...                  ...
# 171  <tensorflow.python.keras.layers.convolutional....  conv5_block3_3_conv
# 172  <tensorflow.python.keras.layers.normalization_...    conv5_block3_3_bn
# 173  <tensorflow.python.keras.layers.merge.Add obje...     conv5_block3_add
# 174  <tensorflow.python.keras.layers.core.Activatio...     conv5_block3_out
# 175  <tensorflow.python.keras.layers.core.Flatten o...              flatten
#
#      Layer Trainable
# 0              False
# 1              False
# 2              False
# 3              False
# 4              False
# ..               ...
# 171             True
# 172             True
# 173             True
# 174             True
# 175             True
#
# [176 rows x 3 columns]

# %%
model = Sequential()
inputShape = img_dims
chanDim = -1   
        
model.add(restnet)

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
        
model.add(Dense(4, activation='softmax'))

# %%
# compile the model
# lr_schedule = schedules.ExponentialDecay(
#     learning_rate,
#     decay_steps=100000,
#     decay_rate=0.96)
# optimizer = SGD(learning_rate=lr_schedule)

optimizer = RMSprop(lr=learning_rate)

model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 212992)            23587712
# _________________________________________________________________
# dense (Dense)                (None, 512)               109052416
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 132,904,836
# Trainable params: 112,732,676
# Non-trainable params: 20,172,160
# _________________________________________________________________

# %%
model.save("mal-model.h5")

# %%
# CHECKPOINT
checkpoint_path="checkpoints/weights-improvement-{epoch:02d}-{val_accuracy:.2f}.hdf5"
checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
datagen = ImageDataGenerator(zoom_range=0.3, rotation_range=50,
 width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
 horizontal_flip=True, vertical_flip=True, fill_mode='nearest')

# %%
# train the model
H = model.fit(datagen.flow(X_train, y_train, batch_size=batch_size),epochs=epochs,verbose=1,validation_data=(X_test, y_test),steps_per_epoch=len(X_train)/batch_size, callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 542/542 [==============================] - 97s 157ms/step - loss: 1.7662 - accuracy: 0.5457 - val_loss: 0.8769 - val_accuracy: 0.6694
#
# Epoch 00001: val_accuracy improved from -inf to 0.66943, saving model to checkpoints\weights-improvement-01-0.67.hdf5
# Epoch 2/50
# 542/542 [==============================] - 76s 139ms/step - loss: 1.0549 - accuracy: 0.6182 - val_loss: 1.0642 - val_accuracy: 0.6713
#
# Epoch 00002: val_accuracy improved from 0.66943 to 0.67127, saving model to checkpoints\weights-improvement-02-0.67.hdf5
# Epoch 3/50
# 542/542 [==============================] - 75s 138ms/step - loss: 1.0172 - accuracy: 0.6300 - val_loss: 0.9082 - val_accuracy: 0.6796
#
# Epoch 00003: val_accuracy improved from 0.67127 to 0.67956, saving model to checkpoints\weights-improvement-03-0.68.hdf5
# Epoch 4/50
# 542/542 [==============================] - 75s 138ms/step - loss: 0.9588 - accuracy: 0.6513 - val_loss: 1.0085 - val_accuracy: 0.6897
#
# Epoch 00004: val_accuracy improved from 0.67956 to 0.68969, saving model to checkpoints\weights-improvement-04-0.69.hdf5
# Epoch 5/50
# 542/542 [==============================] - 75s 138ms/step - loss: 0.8794 - accuracy: 0.6675 - val_loss: 0.9410 - val_accuracy: 0.6980
#
# Epoch 00005: val_accuracy improved from 0.68969 to 0.69797, saving model to checkpoints\weights-improvement-05-0.70.hdf5
# Epoch 6/50
# 542/542 [==============================] - 76s 139ms/step - loss: 0.9394 - accuracy: 0.6548 - val_loss: 0.8903 - val_accuracy: 0.6961
#
# Epoch 00006: val_accuracy did not improve from 0.69797
# Epoch 7/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.8640 - accuracy: 0.6691 - val_loss: 0.8169 - val_accuracy: 0.7164
#
# Epoch 00007: val_accuracy improved from 0.69797 to 0.71639, saving model to checkpoints\weights-improvement-07-0.72.hdf5
# Epoch 8/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.8892 - accuracy: 0.6652 - val_loss: 0.7850 - val_accuracy: 0.7293
#
# Epoch 00008: val_accuracy improved from 0.71639 to 0.72928, saving model to checkpoints\weights-improvement-08-0.73.hdf5
# Epoch 9/50
# 542/542 [==============================] - 77s 141ms/step - loss: 0.8489 - accuracy: 0.6910 - val_loss: 1.0920 - val_accuracy: 0.7090
#
# Epoch 00009: val_accuracy did not improve from 0.72928
# Epoch 10/50
# 542/542 [==============================] - 77s 141ms/step - loss: 0.8654 - accuracy: 0.6765 - val_loss: 0.7430 - val_accuracy: 0.7394
#
# Epoch 00010: val_accuracy improved from 0.72928 to 0.73941, saving model to checkpoints\weights-improvement-10-0.74.hdf5
# Epoch 11/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.8286 - accuracy: 0.6978 - val_loss: 0.7095 - val_accuracy: 0.7532
#
# Epoch 00011: val_accuracy improved from 0.73941 to 0.75322, saving model to checkpoints\weights-improvement-11-0.75.hdf5
# Epoch 12/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.8091 - accuracy: 0.7023 - val_loss: 0.8905 - val_accuracy: 0.7311
#
# Epoch 00012: val_accuracy did not improve from 0.75322
# Epoch 13/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.8168 - accuracy: 0.7042 - val_loss: 0.7883 - val_accuracy: 0.7477
#
# Epoch 00013: val_accuracy did not improve from 0.75322
# Epoch 14/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.7815 - accuracy: 0.7177 - val_loss: 0.6858 - val_accuracy: 0.7569
#
# Epoch 00014: val_accuracy improved from 0.75322 to 0.75691, saving model to checkpoints\weights-improvement-14-0.76.hdf5
# Epoch 15/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.7948 - accuracy: 0.7204 - val_loss: 0.7940 - val_accuracy: 0.7597
#
# Epoch 00015: val_accuracy improved from 0.75691 to 0.75967, saving model to checkpoints\weights-improvement-15-0.76.hdf5
# Epoch 16/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.7890 - accuracy: 0.7349 - val_loss: 0.6999 - val_accuracy: 0.7486
#
# Epoch 00016: val_accuracy did not improve from 0.75967
# Epoch 17/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.7730 - accuracy: 0.7078 - val_loss: 0.6691 - val_accuracy: 0.7597
#
# Epoch 00017: val_accuracy did not improve from 0.75967
# Epoch 18/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.7592 - accuracy: 0.7252 - val_loss: 0.7093 - val_accuracy: 0.7551
#
# Epoch 00018: val_accuracy did not improve from 0.75967
# Epoch 19/50
# 542/542 [==============================] - 77s 142ms/step - loss: 0.8009 - accuracy: 0.7271 - val_loss: 0.7216 - val_accuracy: 0.7578
#
# Epoch 00019: val_accuracy did not improve from 0.75967
# Epoch 20/50
# 542/542 [==============================] - 77s 141ms/step - loss: 0.7793 - accuracy: 0.7232 - val_loss: 0.7016 - val_accuracy: 0.7615
#
# Epoch 00020: val_accuracy improved from 0.75967 to 0.76151, saving model to checkpoints\weights-improvement-20-0.76.hdf5
# Epoch 21/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.7270 - accuracy: 0.7349 - val_loss: 0.7089 - val_accuracy: 0.7293
#
# Epoch 00021: val_accuracy did not improve from 0.76151
# Epoch 22/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.7543 - accuracy: 0.7304 - val_loss: 0.6654 - val_accuracy: 0.7532
#
# Epoch 00022: val_accuracy did not improve from 0.76151
# Epoch 23/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.7639 - accuracy: 0.7485 - val_loss: 0.6467 - val_accuracy: 0.7716
#
# Epoch 00023: val_accuracy improved from 0.76151 to 0.77164, saving model to checkpoints\weights-improvement-23-0.77.hdf5
# Epoch 24/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.7390 - accuracy: 0.7501 - val_loss: 0.7186 - val_accuracy: 0.7468
#
# Epoch 00024: val_accuracy did not improve from 0.77164
# Epoch 25/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.6822 - accuracy: 0.7499 - val_loss: 0.7083 - val_accuracy: 0.7468
#
# Epoch 00025: val_accuracy did not improve from 0.77164
# Epoch 26/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.6753 - accuracy: 0.7570 - val_loss: 0.6839 - val_accuracy: 0.7698
#
# Epoch 00026: val_accuracy did not improve from 0.77164
# Epoch 27/50
# 542/542 [==============================] - 76s 140ms/step - loss: 0.6908 - accuracy: 0.7396 - val_loss: 0.6983 - val_accuracy: 0.7762
#
# Epoch 00027: val_accuracy improved from 0.77164 to 0.77624, saving model to checkpoints\weights-improvement-27-0.78.hdf5
# Epoch 28/50
# 542/542 [==============================] - 77s 142ms/step - loss: 0.7083 - accuracy: 0.7539 - val_loss: 0.5902 - val_accuracy: 0.7901
#
# Epoch 00028: val_accuracy improved from 0.77624 to 0.79006, saving model to checkpoints\weights-improvement-28-0.79.hdf5
# Epoch 29/50
# 542/542 [==============================] - 78s 144ms/step - loss: 0.6896 - accuracy: 0.7544 - val_loss: 0.7390 - val_accuracy: 0.7606
#
# Epoch 00029: val_accuracy did not improve from 0.79006
# Epoch 30/50
# 542/542 [==============================] - 77s 142ms/step - loss: 0.7593 - accuracy: 0.7665 - val_loss: 0.7190 - val_accuracy: 0.7569
#
# Epoch 00030: val_accuracy did not improve from 0.79006
# Epoch 31/50
# 542/542 [==============================] - 77s 141ms/step - loss: 0.6823 - accuracy: 0.7503 - val_loss: 0.6521 - val_accuracy: 0.7891
#
# Epoch 00031: val_accuracy did not improve from 0.79006
# Epoch 32/50
# 542/542 [==============================] - 77s 141ms/step - loss: 0.6850 - accuracy: 0.7722 - val_loss: 0.6532 - val_accuracy: 0.7855
#
# Epoch 00032: val_accuracy did not improve from 0.79006
# Epoch 33/50
# 542/542 [==============================] - 77s 141ms/step - loss: 0.6876 - accuracy: 0.7782 - val_loss: 0.7152 - val_accuracy: 0.7459
#
# Epoch 00033: val_accuracy did not improve from 0.79006
# Epoch 34/50
# 542/542 [==============================] - 77s 141ms/step - loss: 0.6935 - accuracy: 0.7654 - val_loss: 0.7601 - val_accuracy: 0.7624
#
# Epoch 00034: val_accuracy did not improve from 0.79006
# Epoch 35/50
# 542/542 [==============================] - 77s 141ms/step - loss: 0.6792 - accuracy: 0.7561 - val_loss: 0.7340 - val_accuracy: 0.7238
#
# Epoch 00035: val_accuracy did not improve from 0.79006
# Epoch 36/50
# 542/542 [==============================] - 77s 141ms/step - loss: 0.6215 - accuracy: 0.7812 - val_loss: 0.5941 - val_accuracy: 0.7781
# Epoch 00036: val_accuracy did not improve from 0.79006
# Epoch 37/50
# 542/542 [==============================] - 81s 149ms/step - loss: 0.6496 - accuracy: 0.7825 - val_loss: 0.5737 - val_accuracy: 0.8002
#
# Epoch 00037: val_accuracy improved from 0.79006 to 0.80018, saving model to checkpoints\weights-improvement-37-0.80.hdf5
# Epoch 38/50
# 542/542 [==============================] - 92s 169ms/step - loss: 0.6608 - accuracy: 0.7739 - val_loss: 0.7538 - val_accuracy: 0.7486
#
# Epoch 00038: val_accuracy did not improve from 0.80018
# Epoch 39/50
# 542/542 [==============================] - 84s 155ms/step - loss: 0.6402 - accuracy: 0.7793 - val_loss: 0.6501 - val_accuracy: 0.7624
#
# Epoch 00039: val_accuracy did not improve from 0.80018
# Epoch 40/50
# 542/542 [==============================] - 80s 146ms/step - loss: 0.6396 - accuracy: 0.7816 - val_loss: 0.6563 - val_accuracy: 0.7818
#
# Epoch 00040: val_accuracy did not improve from 0.80018
# Epoch 41/50
# 542/542 [==============================] - 79s 145ms/step - loss: 0.6558 - accuracy: 0.7777 - val_loss: 0.7011 - val_accuracy: 0.7799
#
# Epoch 00041: val_accuracy did not improve from 0.80018
# Epoch 42/50
# 542/542 [==============================] - 79s 144ms/step - loss: 0.6828 - accuracy: 0.7864 - val_loss: 0.7071 - val_accuracy: 0.8011
#
# Epoch 00042: val_accuracy improved from 0.80018 to 0.80110, saving model to checkpoints\weights-improvement-42-0.80.hdf5
# Epoch 43/50
# 542/542 [==============================] - 78s 144ms/step - loss: 0.6653 - accuracy: 0.7789 - val_loss: 0.5975 - val_accuracy: 0.8039
#
# Epoch 00043: val_accuracy improved from 0.80110 to 0.80387, saving model to checkpoints\weights-improvement-43-0.80.hdf5
# Epoch 44/50
# 542/542 [==============================] - 83s 152ms/step - loss: 0.6753 - accuracy: 0.7737 - val_loss: 0.6356 - val_accuracy: 0.7836
#
# Epoch 00044: val_accuracy did not improve from 0.80387
# Epoch 45/50
# 542/542 [==============================] - 77s 142ms/step - loss: 0.6009 - accuracy: 0.7977 - val_loss: 0.6509 - val_accuracy: 0.8057
#
# Epoch 00045: val_accuracy improved from 0.80387 to 0.80571, saving model to checkpoints\weights-improvement-45-0.81.hdf5
# Epoch 46/50
# 542/542 [==============================] - 77s 142ms/step - loss: 0.6784 - accuracy: 0.7977 - val_loss: 0.7008 - val_accuracy: 0.7855
#
# Epoch 00046: val_accuracy did not improve from 0.80571
# Epoch 47/50
# 542/542 [==============================] - 77s 142ms/step - loss: 0.6920 - accuracy: 0.7824 - val_loss: 0.6527 - val_accuracy: 0.8057
#
# Epoch 00047: val_accuracy did not improve from 0.80571
# Epoch 48/50
# 542/542 [==============================] - 76s 141ms/step - loss: 0.6857 - accuracy: 0.7754 - val_loss: 0.6146 - val_accuracy: 0.8020
#
# Epoch 00048: val_accuracy did not improve from 0.80571
# Epoch 49/50
# 542/542 [==============================] - 77s 142ms/step - loss: 0.6285 - accuracy: 0.7857 - val_loss: 0.6973 - val_accuracy: 0.7716
#
# Epoch 00049: val_accuracy did not improve from 0.80571
# Epoch 50/50
# 542/542 [==============================] - 78s 143ms/step - loss: 0.6136 - accuracy: 0.7981 - val_loss: 0.6742 - val_accuracy: 0.7772
#
# Epoch 00050: val_accuracy did not improve from 0.80571

# %%
# plot training/validation loss/accuracy
plt.style.use("ggplot")
plt.figure(figsize=(20,10))
N = epochs
plt.plot(np.arange(0,N), H.history["loss"], label="Training loss")
plt.plot(np.arange(0,N), H.history["val_loss"], label="Validation loss")
plt.title("Training/Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(loc="upper right")
plt.savefig("checkpoints/loss.png")
plt.show()


plt.style.use("ggplot")
plt.figure(figsize=(20,10))
plt.plot(np.arange(0,N), H.history["accuracy"], label="Training accuracy")
plt.plot(np.arange(0,N), H.history["val_accuracy"], label="Validation accuracy")
plt.title("Training/Validation Loss and Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Loss/Accuracy")
plt.legend(loc="upper right")
plt.savefig("checkpoints/accuracy.png")
plt.show()
